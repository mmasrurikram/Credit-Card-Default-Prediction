# %%
## import necessary modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('darkgrid')

## Display all the columns of the dataframe

pd.pandas.set_option('display.max_columns',None)

# %%
df=pd.read_csv("UCI_Credit_Card.csv")
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2     3913.0     3102.0      689.0        0.0        0.0
# 1      0      2     2682.0     1725.0     2682.0     3272.0     3455.0
# 2      0      0    29239.0    14027.0    13559.0    14331.0    14948.0
# 3      0      0    46990.0    48233.0    49291.0    28314.0    28959.0
# 4      0      0     8617.0     5670.0    35835.0    20940.0    19146.0
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %% [markdown]
# ID: ID of each client
# LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# SEX: Gender (1=male, 2=female)
# EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# MARRIAGE: Marital status (1=married, 2=single, 3=others)
# AGE: Age in years
# PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above)
# PAY_2: Repayment status in August, 2005 (scale same as above)
# PAY_3: Repayment status in July, 2005 (scale same as above)
# PAY_4: Repayment status in June, 2005 (scale same as above)
# PAY_5: Repayment status in May, 2005 (scale same as above)
# PAY_6: Repayment status in April, 2005 (scale same as above)
# BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# default.payment.next.month: Default payment (1=yes, 0=no)

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
plt.subplots(figsize=(30,20))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
corr = df.corr()[['default.payment.next.month']]
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %% [markdown]
# # Data Pre-Processing

# %% [markdown]
# ## EDA

# %% [markdown]
# ### default.payment.next.month

# %%
df.rename(columns ={"default.payment.next.month": "default"}, inplace = True)

# %%
df["default"].unique()
# Out:
# array([1, 0])

# %%
df["default"].value_counts()
# Out:
# default
# 0    23364
# 1     6636
# Name: count, dtype: int64

# %%
# 0= no default, 1= default
plt.figure(figsize=(7,5))
sns.countplot(x="default",order=[0,1],data=df).set_title("Default Payment Next Month",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Default Payment Next Month')

# %% [markdown]
# ### Sex

# %%
df["SEX"].value_counts()
# Out:
# SEX
# 2    18112
# 1    11888
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="SEX",order=[1,2],data=df).set_title("Sex",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Sex')

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="SEX",order=[1,2],hue="default",data=df).set_title("Sex",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Sex')

# %% [markdown]
# ### MARRIAGE

# %%
df["MARRIAGE"].unique()
# Out:
# array([1, 2, 3, 0])

# %%
df["MARRIAGE"].value_counts(ascending=True)
# Out:
# MARRIAGE
# 0       54
# 3      323
# 1    13659
# 2    15964
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="MARRIAGE",order=[0,1,2,3],data=df).set_title("Marriage",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Marriage')

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="MARRIAGE",order=[0,1,2,3],hue="default",data=df).set_title("Marriage",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'Marriage')

# %% [markdown]
# ### EDUCATION

# %%
df["EDUCATION"].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0])

# %%
df["EDUCATION"].value_counts(ascending=True)
# Out:
# EDUCATION
# 0       14
# 6       51
# 4      123
# 5      280
# 3     4917
# 1    10585
# 2    14030
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="EDUCATION",order=[0,1,2,3],data=df).set_title("EDUCATION",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'EDUCATION')

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="EDUCATION",order=[0,1,2,3],hue="default",data=df).set_title("EDUCATION",fontsize=15,fontdict={"weight": "bold"})
# Out:
# Text(0.5, 1.0, 'EDUCATION')

# %% [markdown]
# ###  Age

# %%
sns.displot(data=df, x="AGE",height=5, aspect=2)

# %%
sns.displot(data=df, x="AGE",hue="default",kde=True,height=5, aspect=2)

# %% [markdown]
# ### LIMIT_BAL

# %%
sns.boxplot(x="default",y="LIMIT_BAL",data=df)
# Out:
# <Axes: xlabel='default', ylabel='LIMIT_BAL'>

# %% [markdown]
# ### PAY_0

# %%
df["PAY_0"].unique()
# Out:
# array([ 2, -1,  0, -2,  1,  3,  4,  8,  7,  5,  6])

# %%
df["PAY_0"].value_counts()
# Out:
# PAY_0
#  0    14737
# -1     5686
#  1     3688
# -2     2759
#  2     2667
#  3      322
#  4       76
#  5       26
#  8       19
#  6       11
#  7        9
# Name: count, dtype: int64

# %%
sns.countplot(x="PAY_0",data=df)
# Out:
# <Axes: xlabel='PAY_0', ylabel='count'>

# %% [markdown]
# ### PAY_2

# %%
df["PAY_2"].unique()
# Out:
# array([ 2,  0, -1, -2,  3,  5,  7,  4,  1,  6,  8])

# %%
df["PAY_2"].value_counts()
# Out:
# PAY_2
#  0    15730
# -1     6050
#  2     3927
# -2     3782
#  3      326
#  4       99
#  1       28
#  5       25
#  7       20
#  6       12
#  8        1
# Name: count, dtype: int64

# %%
sns.countplot(x="PAY_2",data=df)
# Out:
# <Axes: xlabel='PAY_2', ylabel='count'>

# %% [markdown]
# ### PAY_3

# %%
df["PAY_3"].unique()
# Out:
# array([-1,  0,  2, -2,  3,  4,  6,  7,  1,  5,  8])

# %%
df["PAY_3"].value_counts()
# Out:
# PAY_3
#  0    15764
# -1     5938
# -2     4085
#  2     3819
#  3      240
#  4       76
#  7       27
#  6       23
#  5       21
#  1        4
#  8        3
# Name: count, dtype: int64

# %%
sns.countplot(x="PAY_3",data=df)
# Out:
# <Axes: xlabel='PAY_3', ylabel='count'>

# %% [markdown]
# ### PAY_4

# %%
df["PAY_4"].unique()
# Out:
# array([-1,  0, -2,  2,  3,  4,  5,  7,  6,  1,  8])

# %%
df["PAY_4"].value_counts()
# Out:
# PAY_4
#  0    16455
# -1     5687
# -2     4348
#  2     3159
#  3      180
#  4       69
#  7       58
#  5       35
#  6        5
#  1        2
#  8        2
# Name: count, dtype: int64

# %%
sns.countplot(x="PAY_4",data=df)
# Out:
# <Axes: xlabel='PAY_4', ylabel='count'>

# %% [markdown]
# ### PAY_5

# %%
df["PAY_5"].unique()
# Out:
# array([-2,  0, -1,  2,  3,  5,  4,  7,  8,  6])

# %%
df["PAY_5"].value_counts()
# Out:
# PAY_5
#  0    16947
# -1     5539
# -2     4546
#  2     2626
#  3      178
#  4       84
#  7       58
#  5       17
#  6        4
#  8        1
# Name: count, dtype: int64

# %%
sns.countplot(x="PAY_5",data=df)
# Out:
# <Axes: xlabel='PAY_5', ylabel='count'>

# %% [markdown]
# ### PAY_6

# %%
df["PAY_6"].unique()
# Out:
# array([-2,  2,  0, -1,  3,  6,  4,  7,  8,  5])

# %%
df["PAY_6"].value_counts()
# Out:
# PAY_6
#  0    16286
# -1     5740
# -2     4895
#  2     2766
#  3      184
#  4       49
#  7       46
#  6       19
#  5       13
#  8        2
# Name: count, dtype: int64

# %%
sns.countplot(x="PAY_6",data=df)
# Out:
# <Axes: xlabel='PAY_6', ylabel='count'>

# %% [markdown]
# ### BILL_AMT1

# %%
sns.boxplot(x="default",y="BILL_AMT1",data=df)
# Out:
# <Axes: xlabel='default', ylabel='BILL_AMT1'>

# %% [markdown]
# ### BILL_AMT2

# %%
sns.boxplot(x="default",y="BILL_AMT2",data=df)
# Out:
# <Axes: xlabel='default', ylabel='BILL_AMT2'>

# %% [markdown]
# ### BILL_AMT3

# %%
sns.boxplot(x="default",y="BILL_AMT3",data=df)
# Out:
# <Axes: xlabel='default', ylabel='BILL_AMT3'>

# %% [markdown]
# ### BILL_AMT4

# %%
sns.boxplot(x="default",y="BILL_AMT4",data=df)
# Out:
# <Axes: xlabel='default', ylabel='BILL_AMT4'>

# %% [markdown]
# ### BILL_AMT5

# %%
sns.boxplot(x="default",y="BILL_AMT5",data=df)
# Out:
# <Axes: xlabel='default', ylabel='BILL_AMT5'>

# %% [markdown]
# ### BILL_AMT6

# %%
sns.boxplot(x="default",y="BILL_AMT6",data=df)
# Out:
# <Axes: xlabel='default', ylabel='BILL_AMT6'>

# %% [markdown]
# ### PAY_AMT1

# %%
sns.boxplot(x="default",y="PAY_AMT1",data=df)
# Out:
# <Axes: xlabel='default', ylabel='PAY_AMT1'>

# %% [markdown]
# ### PAY_AMT2

# %%
sns.boxplot(x="default",y="PAY_AMT2",data=df)
# Out:
# <Axes: xlabel='default', ylabel='PAY_AMT2'>

# %% [markdown]
# ### PAY_AMT3

# %%
sns.boxplot(x="default",y="PAY_AMT3",data=df)
# Out:
# <Axes: xlabel='default', ylabel='PAY_AMT3'>

# %% [markdown]
# ### PAY_AMT4

# %%
sns.boxplot(x="default",y="PAY_AMT4",data=df)
# Out:
# <Axes: xlabel='default', ylabel='PAY_AMT4'>

# %% [markdown]
# ### PAY_AMT5

# %%
sns.boxplot(x="default",y="PAY_AMT5",data=df)
# Out:
# <Axes: xlabel='default', ylabel='PAY_AMT5'>

# %% [markdown]
# ### PAY_AMT6

# %%
sns.boxplot(x="default",y="PAY_AMT6",data=df)
# Out:
# <Axes: xlabel='default', ylabel='PAY_AMT6'>

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Outlier Handling on LIMIT_BAL

# %%
df_default_1=df[df["default"]==1]

# %%
df_default_1.shape
# Out:
# (6636, 25)

# %%
max_thresold=df_default_1["LIMIT_BAL"].quantile(0.95)
max_thresold
# Out:
# np.float64(360000.0)

# %%
df_default_1[df_default_1["LIMIT_BAL"]<max_thresold].shape[0]
# Out:
# 6188

# %%
df_default_1=df_default_1[df_default_1["LIMIT_BAL"]<max_thresold]

# %%
df_default_1.shape
# Out:
# (6188, 25)

# %%
sns.boxplot(x="LIMIT_BAL",data=df_default_1)
# Out:
# <Axes: xlabel='LIMIT_BAL'>

# %%
df_default_0=df[df["default"]==0]

# %%
df_default_0.shape
# Out:
# (23364, 25)

# %%
max_thresold_0=df_default_0["LIMIT_BAL"].quantile(0.95)
max_thresold_0
# Out:
# np.float64(450000.0)

# %%
df_default_0[df_default_0["LIMIT_BAL"]<max_thresold].shape[0]
# Out:
# 20455

# %%
df_default_0=df_default_0[df_default_0["LIMIT_BAL"]<max_thresold]

# %%
df_default_0.shape
# Out:
# (20455, 25)

# %%
sns.boxplot(x="LIMIT_BAL",data=df_default_0)
# Out:
# <Axes: xlabel='LIMIT_BAL'>

# %%
df = pd.concat([df_default_0, df_default_1], ignore_index=True, sort=False)

# %%
df.shape
# Out:
# (26643, 25)

# %% [raw]
# Note: There will be a lot of data loss if i used outlier handling in all the feature that has oulier.That's why i just handled outlier on LIMIT_BAL feature.

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### information gain method

# %%
# # Dividing dependent and independent variables
X = df.drop("default", axis=1)
y = df["default"]

# %%
from sklearn.feature_selection import mutual_info_classif

importances=mutual_info_classif(X,y)
feat_importances=pd.Series(importances,df.columns[0:len(df.columns)-1])
feat_importances.plot(kind="barh")
plt.grid(True)
plt.show()

# %%
#feat_importances
#taking 0.01
#Limit_BAL,PAY_0,PAY_2,PAY_3,PAY_4,PAY_5,PAY_6,PAY_AMT1,PAY_AMT2,PAY_AMT3,PAY_AMT6

# %%
X=pd.DataFrame({"LIMIT_BAL":df["LIMIT_BAL"],"PAY_0":df["PAY_0"],"PAY_2":df["PAY_2"],"PAY_3":df["PAY_3"],"PAY_4":df["PAY_4"],"PAY_5":df["PAY_5"],"PAY_6":df["PAY_6"],"PAY_AMT1":df["PAY_AMT1"],"PAY_AMT2":df["PAY_AMT2"],"PAY_AMT3":df["PAY_AMT3"],"PAY_AMT6":df["PAY_AMT6"]})

# %%
X.head(2)
# Out:
#    LIMIT_BAL  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  PAY_AMT1  PAY_AMT2  \
# 0    90000.0      0      0      0      0      0      0    1518.0    1500.0
# 1    50000.0      0      0      0      0      0      0    2000.0    2019.0
#
#    PAY_AMT3  PAY_AMT6
# 0    1000.0    5000.0
# 1    1200.0    1000.0

# %% [raw]
# Note: I have applied feature selection technique like  coorelation, lasso,information gain.Finally, i have applied information gain method in this dataset.Because i have gained good accuracy with less feature using information gain technique.

# %%
X.shape
# Out:
# (26643, 11)

# %%
y.value_counts()
# Out:
# default
# 0    20455
# 1     6188
# Name: count, dtype: int64

# %%
# Sampling
# Balanacing dataset
from imblearn.over_sampling import SMOTE 
from collections import Counter

sampler = SMOTE()
X, y = sampler.fit_resample(X, y)

print('SMOTE {}'.format(Counter(y)))
# Out:
# SMOTE Counter({0: 20455, 1: 20455})

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100,random_state=0)
rf_model=clf.fit(X_train, y_train)
y_pred=rf_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix,  roc_curve, auc
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      4158
#            1       0.83      0.79      0.81      4024
#
#     accuracy                           0.82      8182
#    macro avg       0.82      0.82      0.82      8182
# weighted avg       0.82      0.82      0.82      8182

# %% [raw]
# Note: I have used machine learning algorithm like Logistic regression,Decision tree,KNN,Random forest,SVM,Xgboost in this dataset.Finally,i used random forest algorithm in this dataset because of good accuracy.

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[3529,  629],
#        [ 842, 3182]])

# %%
x_axis_labels = ['Not Exit','Exit']
y_axis_labels = ['Not Exit','Exit']

confusion_m=confusion_matrix(y_test,y_pred)
sns.heatmap(confusion_m, annot=True,cmap='Greens', xticklabels=x_axis_labels, yticklabels=y_axis_labels)

plt.xlabel('Predicted Label')
plt.ylabel('Actual Label')
# Out:
# Text(50.722222222222214, 0.5, 'Actual Label')

# %% [markdown]
# ## Saving Model

# %%
import pickle
pickle.dump(rf_model, open('pickle.pkl','wb'))

# %%
# Calculate ROC Curve and AUC
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# # Hypothesis Test

# %%
from scipy.stats import binomtest

# model's accuracy
model_accuracy = 0.82  
n_samples = len(y_test)  

# Expected accuracy for random guessing (baseline)
random_guess_accuracy = 1 / len(y.unique()) 

# Perform the Binomial test
test_result = binomtest(k=int(model_accuracy * n_samples), n=n_samples, p=random_guess_accuracy)

print(f"P-value: {test_result.pvalue}")

if test_result.pvalue < 0.05:
    print("Reject the null hypothesis: Model performs significantly better than random guessing.")
else:
    print("Fail to reject the null hypothesis: Model does not perform significantly better.")
# Out:
# P-value: 0.0
# Reject the null hypothesis: Model performs significantly better than random guessing.
